# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
encodings=['utf-8','latin1','ISO-8859-1','cp1252']
file_path='spam.csv'
for encoding in encodings:
    try:
        df=pd.read_csv(file_path,encoding=encoding)
        print(f"File successfully read with encoding:{encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to read with encoding:{encoding}")
        continue
if 'df' in locals():
    print("CSV file has been successfully loaded.")
else:
    print("All encoding attepts failed.")
# Out:
# Failed to read with encoding:utf-8
# File successfully read with encoding:latin1
# CSV file has been successfully loaded.

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 4857   ham                                              Ok...        NaN
# 4234  spam  FREEMSG: Our records indicate you may be entit...        NaN
# 3593  spam  Do you want a New Nokia 3510i Colour Phone Del...        NaN
# 3958   ham                           Have a nice day my dear.        NaN
# 743    ham                 Ok. There may be a free gym about.        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4857        NaN        NaN
# 4234        NaN        NaN
# 3593        NaN        NaN
# 3958        NaN        NaN
# 743         NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
#data cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#drop last 3 cols
df.drop(columns=['Unnamed:2','Unnamed:3','Unnamed:4'],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5528   ham  Its just the effect of irritation. Just ignore it        NaN
# 5480   ham                Have you seen who's back at Holby?!        NaN
# 30     ham  Wait that's still not all that clear, were you...        NaN
# 1593  spam  PRIVATE! Your 2003 Account Statement for shows...        NaN
# 1799   ham       If we hit it off, you can move in with me :)        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5528        NaN        NaN
# 5480        NaN        NaN
# 30          NaN        NaN
# 1593        NaN        NaN
# 1799        NaN        NaN

# %%
#remaining cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text Unnamed: 2  \
# 1414    ham  So wats ur opinion abt him and how abt is char...        NaN
# 2609    ham             Awesome, text me when you're restocked        NaN
# 1421    ham                        Do you work all this week ?        NaN
# 4647    ham             We are okay. Going to sleep now. Later        NaN
# 2953    ham  Think i might have to give it a miss. Am teach...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1414        NaN        NaN
# 2609        NaN        NaN
# 1421        NaN        NaN
# 4647        NaN        NaN
# 2953        NaN        NaN

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text Unnamed: 2  \
# 0       0  Go until jurong point, crazy.. Available only ...        NaN
# 1       0                      Ok lar... Joking wif u oni...        NaN
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3       0  U dun say so early hor... U c already then say...        NaN
# 4       0  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
#missing values
df.isnull().sum()
# Out:
# target           0
# text             0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
#check duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
#remove duplicates
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 5)

# %%
#EDA
df.head()
# Out:
#    target                                               text Unnamed: 2  \
# 0       0  Go until jurong point, crazy.. Available only ...        NaN
# 1       0                      Ok lar... Joking wif u oni...        NaN
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3       0  U dun say so early hor... U c already then say...        NaN
# 4       0  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
#data is imbalanced
import nltk
# !pip install nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.loc[:, 'num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text Unnamed: 2  \
# 0       0  Go until jurong point, crazy.. Available only ...        NaN
# 1       0                      Ok lar... Joking wif u oni...        NaN
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3       0  U dun say so early hor... U c already then say...        NaN
# 4       0  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4  num_characters
# 0        NaN        NaN             111
# 1        NaN        NaN              29
# 2        NaN        NaN             155
# 3        NaN        NaN              49
# 4        NaN        NaN              61

# %%
#num of words
df.loc[:, 'num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_4200\2018136620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text Unnamed: 2  \
# 0       0  Go until jurong point, crazy.. Available only ...        NaN
# 1       0                      Ok lar... Joking wif u oni...        NaN
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3       0  U dun say so early hor... U c already then say...        NaN
# 4       0  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4  num_characters  num_words
# 0        NaN        NaN             111         24
# 1        NaN        NaN              29          8
# 2        NaN        NaN             155         37
# 3        NaN        NaN              49         13
# 4        NaN        NaN              61         15

# %%
import nltk

# Assuming 'text' column exists in your DataFrame
# df = ...

# Download NLTK's Punkt tokenizer if you haven't already done so
nltk.download('punkt')

# Function to count the number of sentences in a text
def count_sentences(text):
    sentences = nltk.sent_tokenize(text)
    return len(sentences)

# Add the 'num_sentences' column to the DataFrame using .loc
df.loc[:, 'num_sentences'] = df['text'].apply(count_sentences)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Check if all columns exist in the DataFrame
required_columns = ['num_characters', 'num_words', 'num_sentences']
if all(col in df.columns for col in required_columns):
    # If all columns exist, proceed with describe
    df[required_columns].describe()
else:
    # If any column is missing, print a message or handle the situation accordingly
    missing_columns = [col for col in required_columns if col not in df.columns]
    print(f"The following columns are missing: {missing_columns}")

# %%
if 'num_characters' in df.columns and 'num_words' in df.columns:
    # If the necessary columns exist, proceed with the operation
    df[df['target'] == 0][['num_characters', 'num_words']].describe()
else:
    # If any required column is missing, print a message or handle the situation accordingly
    print("One or more required columns are missing in the DataFrame.")

# %%
#spam
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
print(df.columns)
# Out:
# Index(['target', 'text', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'num_characters', 'num_words', 'num_sentences'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
import warnings
warnings.filterwarnings("ignore")
sns.pairplot(df,hue='target')

# %%
import seaborn as sns
import pandas as pd

# Assuming you have a DataFrame named df
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [2, 3, 4, 5, 6],
    'C': [3, 4, 5, 6, 7]
}

df = pd.DataFrame(data)

# Now you can use Seaborn's heatmap function to visualize the correlation matrix of your DataFrame
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
#Data Processing
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Initialize Porter stemmer
ps = PorterStemmer()

def transfrom_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
transformed_text = transfrom_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight,k? I've cried enough today.")
print(transformed_text)
# Out:
# i gon na be home soon and i do want to talk about thi stuff anymor tonight k i cri enough today

# %%
import pandas as pd

# Assuming you have a DataFrame named df
data = {
    'text': ['Sample text 1', 'Sample text 2', 'Sample text 3']
}

df = pd.DataFrame(data)

# Now you can access the 'text' column at index 10
text_value = df['text'][0]
print(text_value)
if len(df) > 10:
    text_value = df['text'][10]  # Access the text value at index 10
    print(text_value)
else:
    print("Index 10 is not within the range of the DataFrame.")
# Out:
# Sample text 1
# Index 10 is not within the range of the DataFrame.

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#             text transformed_text
# 0  Sample Text 1    sample text 1
# 1  Sample Text 2    sample text 2
# 2  Sample Text 3    sample text 3

# %%
pip install wordcloud
# Out:
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 325.1 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/300.2 kB 326.8 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/300.2 kB 847.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/300.2 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
import pandas as pd
from wordcloud import WordCloud

# Define or load the DataFrame 'df'
# Assuming you have a DataFrame named df with 'target' and 'transformed_text' columns
# For example:
df = pd.DataFrame({
    'target': [0, 1, 0, 1],
    'transformed_text': [
        'spam text one',
        'spam text two',
        'non-spam text one',
        'non-spam text two'
    ]
})

# Generate the word cloud for the 'transformed_text' column where 'target' is equal to 1
spam_wc = WordCloud().generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# Now you can display or save the word cloud as needed

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=' '))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target   transformed_text
# 0       0      spam text one
# 1       1      spam text two
# 2       0  non-spam text one
# 3       1  non-spam text two

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 6

# %%
import seaborn as sns
from collections import Counter  

# Assuming you have already defined 'spam_corpus'

# Create a Counter object from spam_corpus and get the most common 30 words
counter = Counter(spam_corpus)
most_common_words = counter.most_common(30)

# Convert the most common words into a DataFrame for visualization
df_most_common = pd.DataFrame(most_common_words, columns=['Word', 'Frequency'])

# Create a bar plot using Seaborn
sns.barplot(x='Word', y='Frequency', data=df_most_common)
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus=[]
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 6

# %%
import seaborn as sns
from collections import Counter 
sns.barplot(x='Word', y='Frequency', data=df_most_common)
plt.xticks(rotation='vertical')
plt.show()

# %%
#text vectorization
#using Bag of Words
df.head()
# Out:
#    target   transformed_text
# 0       0      spam text one
# 1       1      spam text two
# 2       0  non-spam text one
# 3       1  non-spam text two

# %%
#Model Building
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = cv.fit_transform(df['transformed_text']).toarray()

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#X = scaler.fit_transform(X)

# %%
# appending the num_character col to X
#X = np.hstack((X,df['num_characters'].values.reshape(-1,1)))

# %%
X.shape
# Out:
# (4, 5)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.0
# [[0 1]
#  [0 0]]
# 0.0

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.0
# [[0 1]
#  [0 0]]
# 0.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 1.0
# [[1]]
# 0.0
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# tfidf --> MNB

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.0, 0.0)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.0
# Precision -  0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 6
#       2 precision_scores = []
#       4 for name,clf in clfs.items():
# ----> 6     current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
#       8     print("For ",name)
#       9     print("Accuracy - ",current_accuracy)
#
# Cell In[83], line 3, in train_classifier(clf, X_train, y_train, X_test, y_test)
#       1 def train_classifier(clf,X_train,y_train,X_test,y_test):
#       2     clf.fit(X_train,y_train)
# ----> 3     y_pred = clf.predict(X_test)
#       4     accuracy = accuracy_score(y_test,y_pred)
#       5     precision = precision_score(y_test,y_pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:249, in KNeighborsClassifier.predict(self, X)
#     245 if self.weights == "uniform":
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
import pandas as pd

# Assuming you have lists of classifier names, accuracy scores, and precision scores
classifier_names = ['Classifier 1', 'Classifier 2', 'Classifier 3']  # List of classifier names
accuracy_scores = [0.85, 0.92, 0.78]  # List of accuracy scores
precision_scores = [0.88, 0.94, 0.75]  # List of precision scores

# Create a DataFrame to store the performance metrics
performance_df = pd.DataFrame({
    'Classifier': classifier_names,
    'Accuracy': accuracy_scores,
    'Precision': precision_scores
})

# Display the DataFrame
print(performance_df)
# Out:
#      Classifier  Accuracy  Precision
# 0  Classifier 1      0.85       0.88
# 1  Classifier 2      0.92       0.94
# 2  Classifier 3      0.78       0.75

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
#
# NameError: name 'performance_df' is not defined

# %%
performance_df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 performance_df1
#
# NameError: name 'performance_df1' is not defined

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 sns.catplot(x = 'Algorithm', y='value',
# ----> 2                hue = 'variable',data=performance_df1, kind='bar',height=5)
#       3 plt.ylim(0.5,1.0)
#       4 plt.xticks(rotation='vertical')
#
# NameError: name 'performance_df1' is not defined

# %%
# model improve
# 1. Change the max_features parameter of TfIdf
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 3
#       1 # model improve
#       2 # 1. Change the max_features parameter of TfIdf
# ----> 3 temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
# ...

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
new_df = performance_df.merge(temp_df,on='Algorithm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 new_df = performance_df.merge(temp_df,on='Algorithm')
#
# NameError: name 'performance_df' is not defined

# %%
new_df_scaled = new_df.merge(temp_df,on='Algorithm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 new_df_scaled = new_df.merge(temp_df,on='Algorithm')
#
# NameError: name 'new_df' is not defined

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores}).sort_values('Precision_num_chars',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores}).sort_values('Precision_num_chars',ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
new_df_scaled.merge(temp_df,on='Algorithm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 new_df_scaled.merge(temp_df,on='Algorithm')
#
# NameError: name 'new_df_scaled' is not defined

# %%
# Voting Classifier
svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.0
# Precision 0.0

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
from sklearn.model_selection import cross_val_predict

# Assuming you have defined the classifier 'clf' and the dataset 'X' and 'y'

# Reduce the number of splits in cross-validation to the number of samples in the dataset
predictions = cross_val_predict(clf, X, y, cv=len(X))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 6
#       1 from sklearn.model_selection import cross_val_predict
#       3 # Assuming you have defined the classifier 'clf' and the dataset 'X' and 'y'
#       4
#       5 # Reduce the number of splits in cross-validation to the number of samples in the dataset
# ----> 6 predictions = cross_val_predict(clf, X, y, cv=len(X))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1010, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#    1007 X, y, groups = indexable(X, y, groups)
#    1009 cv = check_cv(cv, y, classifier=is_classifier(estimator))
# -> 1010 splits = list(cv.split(X, y, groups))
#    1012 test_indices = np.concatenate([test for _, test in splits])
#    1013 if not _check_is_permutation(test_indices, _num_samples(X)):
#
# ...

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
